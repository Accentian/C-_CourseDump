# %%
from pprint import pprint
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Read json data
json_data = json.loads(open('piezo.json').read())
pprint(json_data)
# Out:
# [{'eij_max': 0.091464,
#   'meta': {'formula': 'AgI',
#            'kpoint_density': 2000,
#            'material_id': 'mp-22925',
#            'nsites': 2,
#            'point_group': '-43m',
#            'poscar': 'Ag1 I1\n'
#                      '1.0\n'
#                      '4.066724 0.000000 2.347924\n'
#                      '1.355575 3.834144 2.347924\n'
#                      '0.000000 0.000000 4.695849\n'
#                      'Ag I\n'
#                      '1 1\n'
#                      'direct\n'
#                      '0.000000 0.000000 0.000000 Ag\n'
#                      '0.250000 0.250000 0.250000 I\n',
#            'space_group': 216,
#            'structure': '#generated using pymatgen\n'
#                         'data_AgI\n'
#                         "_symmetry_space_group_name_H-M   'P 1'\n"
#                         '_cell_length_a   4.69584858\n'
#                         '_cell_length_b   4.69584857\n'
# ...
