# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

# Command use to see the overview of the data
#df
#df.shape
#df.describe()

# %%
# Read the data
piezo = pd.read_csv('piezo.csv')
print(piezo.shape)
piezo.info()
# Out:
# (941, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941 entries, 0 to 940
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   mID         941 non-null    object
#  1   nsites      941 non-null    int64
#  2   formula     941 non-null    object
#  3   pointGroup  941 non-null    object
#  4   spaceGroup  941 non-null    int64
#  5   volume      941 non-null    float64
#  6   a           941 non-null    float64
#  7   b           941 non-null    float64
#  8   c           941 non-null    float64
#  9   alpha       941 non-null    float64
#  10  beta        941 non-null    float64
#  11  gamma       941 non-null    float64
#  12  eij         941 non-null    float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 95.7+ KB

# %%
# Testing rename
rename = {'pointGroup':'pg', 'spaceGroup':'sg'}
piezo.rename(columns = rename, inplace = True)
piezo.head()
# Out:
#         mID  nsites formula    pg   sg     volume         a         b  \
# 0  mp-22925       2     AgI  -43m  216  73.219583  4.695849  4.695849
# 1    mp-406       2    CdTe  -43m  216  72.827208  4.687445  4.687445
# 2   mp-1639       2      BN  -43m  216  11.917209  2.563873  2.563873
# 3  mp-10695       2     ZnS  -43m  216  40.475675  3.853923  3.853923
# 4   mp-2176       2    ZnTe  -43m  216  59.145615  4.373333  4.373333
#
#           c  alpha  beta  gamma       eij
# 0  4.695849   60.0  60.0   60.0  0.091464
# 1  4.687445   60.0  60.0   60.0  0.004848
# 2  2.563873   60.0  60.0   60.0  0.517745
# 3  3.853923   60.0  60.0   60.0  0.030692
# 4  4.373333   60.0  60.0   60.0  0.068884

# %%
plt.figure(1, figsize = (20, 40)) # Figure sizes
for i in range (4,12):
    plt.subplot(3,12,i)
    plt.boxplot(piezo[piezo.columns[i]])
    plt.title(piezo.columns[i])
plt.show()
piezo.describe()
# Out:
#            nsites          sg      volume           a           b           c  \
# count  941.000000  941.000000  941.000000  941.000000  941.000000  941.000000
# mean     7.984060  108.741764  143.011281    5.179138    5.476800    6.274313
# std      3.144864   74.435552   77.312945    1.363093    1.591142    2.543136
# min      2.000000    1.000000   11.917209    2.512979    2.512980    2.507326
# 25%      6.000000   36.000000   87.846934    4.308543    4.478598    4.823594
# 50%      8.000000  121.000000  132.553278    5.040138    5.372655    5.740055
# 75%     10.000000  173.000000  181.163918    5.824267    6.059964    6.903797
# max     14.000000  217.000000  590.136056   17.990321   23.155557   29.678341
#
#             alpha        beta       gamma         eij
# count  941.000000  941.000000  941.000000  941.000000
# mean    85.650408   87.010940   89.761504    0.762904
# std     21.557801   20.823188   24.987816    2.306360
# ...
